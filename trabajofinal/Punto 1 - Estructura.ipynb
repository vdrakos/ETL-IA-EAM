# %% [markdown]
# #Punto 1 - crear la estructura del proyecto

# %%
from pyspark.sql import functions as F
from pyspark.sql import SparkSession

# %%
CATALOG = "insurance_claims"
BRONZE_SCHEMA = "bronze"
SILVER_SCHEMA = "silver"
GOLD_SCHEMA = "gold"
LANDING_SCHEMA = "landing"

VOLUME_NAME = "raw_files"


CUSTOMERS_PATH = f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/customers/customers.csv"
POLICIES_PATH = f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/policies/policies.csv"
CLAIMS_PATH = f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/claims/claims.csv"
METADATA_IMG_PATH = f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/claim_images_metadata/image_metadata.csv"
TELEMATICS_PATH = f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/telematics"
IMAGE_PATH = f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/claim_images"

spark = SparkSession.builder.getOrCreate()

# %%
#Creamos el catalogo
spark.sql(f"CREATE CATALOG IF NOT EXISTS {CATALOG}")

#Creamos los esquemas
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.{BRONZE_SCHEMA}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.{SILVER_SCHEMA}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.{GOLD_SCHEMA}")

#Creamos el volumen
spark.sql(f"CREATE VOLUME IF NOT EXISTS {CATALOG}.{BRONZE_SCHEMA}.{VOLUME_NAME}")
# Out:
# DataFrame[]

# %%
#Creamos las carpetas
dbutils.fs.mkdirs(f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/customers")
dbutils.fs.mkdirs(f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/policies")
dbutils.fs.mkdirs(f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/claims")
dbutils.fs.mkdirs(f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/telematics")
dbutils.fs.mkdirs(f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/training_imgs")
dbutils.fs.mkdirs(f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/claim_imgs")
dbutils.fs.mkdirs(f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}/{VOLUME_NAME}/claim_images_metadata")
# Out:
# True
